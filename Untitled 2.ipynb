# %%
import data
import matplotlib.pyplot as plt

import argparse
parser = argparse.ArgumentParser()

#parser.add_argument('--lr', type=float, default=0.01)
#parser.add_argument('--arch', type=str, default='network.gscnn.GSCNN')
#parser.add_argument('--dataset', type=str, default='cityscapes')
#args = parser.parse_args()


dataset = 'relis3d'
train = 'train'
path_list = 'trainlist.txt'
data_mode = 'rgb'
dataset = data.lidar_and_rgb_both.Relis3D(train, path_list, data_mode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-d28c15e73a8c> in <module>
#      15 path_list = 'trainlist.txt'
#      16 data_mode = 'rgb'
# ---> 17 dataset = data.lidar_and_rgb_both.Relis3D(train, path_list, data_mode)
#
# AttributeError: module 'data' has no attribute 'lidar_and_rgb_both'

# %%
img, mask,edgemap = dataset[0]
#plt.imshow(mask)
print(mask)
#print(mask.shape)
# Out:
# <PIL.Image.Image image mode=L size=1920x1200 at 0x7F13CAE87240>

# %%
import torch
mask = torch.from_numpy(mask)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e8ca9e5bfe77> in <module>
#       1 import torch
# ----> 2 mask = torch.from_numpy(mask)
#
# TypeError: expected np.ndarray (got Image)

# %%
import numpy as np
mask = np.array(mask)
mask = torch.from_numpy(mask)

# %%
print(mask.shape)
print(edgemap.shape)
# Out:
# torch.Size([1200, 1920])
# torch.Size([1, 1200, 1920])

# %%
plt.imshow(edgemap[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1985fa5ab2a3> in <module>
# ----> 1 plt.imshow(edgemap[0])
#
# NameError: name 'plt' is not defined

# %%
# %run -i train.py
# Out:
# /notebooks/checkpoints/SingleDA_SingleBranch_CommonClasses__Source_semantickitti_Target_cityscapes folder already existed
# {'da_mode': 'SingleDA_', 'branch_mode': 'SingleBranch_', 'class_mode': 'CommonClasses_', 'source_dataset': 'semantickitti', 'target_dataset': 'cityscapes', 'other_mode': '', 'train_mode': 'train', 'train_path_list': './dataset/SemanticKitti/trainlist.txt', 'val_path_list': './dataset/CityScapes/trainlist.txt', 'data_mode': 'rgb', 'in_channels': 3, 'image_width': 572, 'image_height': 572, 'num_classes': 20, 'train_data_size': 1000, 'model_path': './checkpoints/SingleDA_SingleBranch_CommonClasses__Source_semantickitti_Target_cityscapes/', 'model_name': '', 'load_model': False, 'multi_level': False, 'batch_size': 1, 'epoches': 100, 'start_epoches': 0, 'learning_rate': 0.0005, 'device': 'cuda:0'}
# ...

# %%
import torch
from models.unet import UNET
# from utils import *
import torch
from models.unet import UNET
# from utils import *
from tqdm import tqdm
import matplotlib.pyplot as plt
from torchvision import transforms
import data
from data import relis3d
import cv2
device = 'cuda:0'
from PIL import Image
from torchvision import transforms

# %%
MODEL_PATH = "YOUR-MODEL-PATH"
train_set = relis3d.Relis3D('vallist.txt')

# %%
img, mask = train_set[25]

# %%
X, y = img.to(device), mask.to(device)

# %%
net = UNET(in_channels=3, classes=20).to(device)
# checkpoint = torch.load("YOUR-MODEL-PATH")
# net.load_state_dict(checkpoint['model_state_dict']
print(net)
# Out:
# UNET(
#   (double_conv_downs): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
predictions = net(X)

# %%
print(predictions.size())
# Out:
# torch.Size([1, 20, 300, 480])

# %%
predictions = torch.nn.functional.softmax(predictions, dim=1)
pred_labels = torch.argmax(predictions, dim=1)

# %%
print(pred_labels.size())
pred = pred_labels.to('cpu')
# Out:
# torch.Size([1, 300, 480])

# %%
trans = transforms.ToPILImage()
plt.imshow(trans(img))
print(img.size())
img = img.reshape(1, 3, 300, 480)
print(img.size())
# Out:
# torch.Size([3, 300, 480])
# torch.Size([1, 3, 300, 480])

# %%
plt.imshow(mask)

# %%
plt.imshow(pred[0])

# %%
SMOOTH = 1e-6
outputs = pred_labels[0]
labels = y
# outputs = outputs.squeeze(1)
print(outputs.size())
print(labels.size())
intersection = (outputs & labels).float().sum((1, 2))
union = (outputs | labels).float().sum((1, 2))
iou = (intersection + SMOOTH) / (union + SMOOTH)
# Out:
# torch.Size([600, 960])
# torch.Size([600, 960])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-bd50ee955a05> in <module>
#       5 print(outputs.size())
#       6 print(labels.size())
# ----> 7 intersection = (outputs & labels).float().sum((1, 2))
#       8 union = (outputs | labels).float().sum((1, 2))
#       9 iou = (intersection + SMOOTH) / (union + SMOOTH)
#
# IndexError: Dimension out of range (expected to be in range of [-2, 1], but got 2)

# %%
print(outputs)
# Out:
# tensor([[6, 6, 6,  ..., 3, 3, 3],
#         [6, 6, 6,  ..., 3, 3, 3],
#         [6, 6, 6,  ..., 3, 3, 3],
#         ...,
#         [2, 2, 2,  ..., 2, 2, 2],
#         [2, 2, 2,  ..., 2, 2, 2],
#         [2, 2, 2,  ..., 2, 2, 2]], device='cuda:0')

# %%
print(labels)
# Out:
# tensor([[ 6,  6,  6,  ...,  3,  3,  3],
#         [ 6,  6,  6,  ...,  3,  3,  3],
#         [ 6,  6,  6,  ...,  3,  3,  3],
#         ...,
#         [17, 17, 17,  ...,  2,  2,  2],
#         [17, 17, 17,  ...,  2,  2,  2],
#         [17, 17, 17,  ...,  2,  2,  2]], device='cuda:0')

# %%
intersection = (outputs & labels).float().sum()
print(intersection)
# Out:
# tensor(4250145., device='cuda:0')

# %%
union = (outputs | labels).float().sum()
print(union)
# Out:
# tensor(4984181., device='cuda:0')

# %%
iou = (intersection + SMOOTH) / (union + SMOOTH)
print(iou)
# Out:
# tensor(0.8527, device='cuda:0')

# %%
thresholded = torch.clamp(20 * (iou - 0.5), 0, 10)/ 10
print(thresholded)
# Out:
# tensor(7.0545, device='cuda:0')
